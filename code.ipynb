# %%
import numpy as np
import matplotlib.pyplot as plt
import string
from sklearn.model_selection import train_test_split

# %%
input_files = ['edgar_allan_poe.txt',
               'robert_frost.txt']

# %%
with open(input_files[0]) as f:
    for _ in range(10):
        print(f.readline().rstrip())
# Out:
# LO! Death hath rear'd himself a throne
# In a strange city, all alone,
# Far down within the dim west
# Where the good, and the bad, and the worst, and the best,
# Have gone to their eternal rest.
#
# There shrines, and palaces, and towers
# Are not like any thing of ours
# Oh no! O no! ours never loom
# To heaven with that ungodly gloom!

# %%
with open(input_files[1]) as f:
    for _ in range(10):
        print(f.readline().rstrip())
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there

# %%
input_texts = []
labels = []

for label, f in enumerate(input_files):
    print(f"{f} corresponds to label {label}")
    
    for line in open(f):
        line = line.rstrip().lower()
        if line:
            line = line.translate(str.maketrans('', '', string.punctuation))
            
            input_texts.append(line)
            labels.append(label)
# Out:
# edgar_allan_poe.txt corresponds to label 0
# robert_frost.txt corresponds to label 1

# %%
for i in range(len(input_texts)):
    print(f"{input_texts[i]}, {labels[i]}")
# Out:
# lo death hath reard himself a throne, 0
# in a strange city all alone, 0
# far down within the dim west, 0
# where the good and the bad and the worst and the best, 0
# have gone to their eternal rest, 0
# there shrines and palaces and towers, 0
# are not like any thing of ours, 0
# oh no o no ours never loom, 0
# to heaven with that ungodly gloom, 0
# timeeaten towers that tremble not, 0
# resemble nothing that is ours, 0
# around by lifting winds forgot, 0
# resignedly beneath the sky, 0
# the melancholy waters lie, 0
# no holy rays from heaven come down, 0
# on the long nighttime of that town, 0
# but light from out the lurid sea, 0
# streams up the turrets silently, 0
# up thrones up longforgotten bowers, 0
# of sculturd ivy and stone flowers, 0
# up domes up spires up kingly halls, 0
# up fanes up babylonlike walls, 0
# up many a melancholy shrine, 0
# whose entablatures intertwine, 0
# the mask the viol and the vine, 0
# there open temples open graves, 0
# are on a level with the waves, 0
# but not the riches there that lie, 0
# in each idols diamond eye, 0
# not the gailyjewelld dead, 0
# tempt the waters from their bed, 0
# for no ripples curl alas, 0
# along that wilderness of glass, 0
# no swellings hint that winds may be, 0
# upon a faroff happier sea, 0
# so blend the turrets and shadows there, 0
# that all seem pendulous in air, 0
# while from the high towers of the town, 0
# death looks gigantically down, 0
# but lo a stir is in the air, 0
# the wave there is a ripple there, 0
# as if the towers had thrown aside, 0
# in slightly sinking the dull tide, 0
# as if the turrettops had given, 0
# a vacuum in the filmy heaven, 0
# the waves have now a redder glow, 0
# the very hours are breathing low, 0
# and when amid no earthly moans, 0
# down down that town shall settle hence, 0
# all hades from a thousand thrones, 0
# shall do it reverence, 0
# and death to some more happy clime, 0
# shall give his undivided time, 0
# the skies they were ashen and sober, 0
# the leaves they were crisped and sere , 0
# the leaves they were withering and sere, 0
# it was night in the lonesome october, 0
# of my most immemorial year, 0
# it was hard by the dim lake of auber, 0
# in the misty mid region of weir , 0
# it was down by the dank tarn of auber, 0
# in the ghoulhaunted woodland of weir, 0
# here once through an alley titanic, 0
# of cypress i roamed with my soul , 0
# of cypress with psyche my soul, 0
# these were days when my heart was volcanic, 0
# as the scoriac rivers that roll , 0
# as the lavas that restlessly roll, 0
# their sulphurous currents down yaanek, 0
# in the ultimate climes of the pole , 0
# that groan as they roll down mount yaanek, 0
# in the realms of the boreal pole, 0
# our talk had been serious and sober, 0
# but our thoughts they were palsied and sere , 0
# our memories were treacherous and sere , 0
# for we knew not the month was october, 0
# and we marked not the night of the year , 0
# ah night of all nights in the year, 0
# we noted not the dim lake of auber , 0
# though once we had journey down here, 0
# remembered not the dank tarn of auber, 0
# nor the ghoulhaunted woodland of weir, 0
# and now as the night was senescent, 0
# and stardials pointed to morn , 0
# as the stardials hinted of morn , 0
# at the end of our path a liquescent, 0
# and nebulous lustre was born, 0
# out of which a miraculous crescent, 0
# arose with a duplicate horn , 0
# astartes bediamonded crescent, 0
# distinct with its duplicate horn, 0
# and i said  she is warmer than dian, 0
# she rolls through an ether of sighs , 0
# she revels in a region of sighs, 0
# she has seen that the tears are not dry on, 0
# these cheeks where the worm never dies, 0
# and has come past the stars of the lion, 0
# to point us the path to the skies , 0
# to the lethean peace of the skies , 0
# come up in despite of the lion, 0
# to shine on us with her bright eyes , 0
# come up through the lair of the lion, 0
# with love in her luminous eyes, 0
# but psyche uplifting her finger, 0
# said  sadly this star i mistrust , 0
# her pallor i strangely mistrust , 0
# oh hasten  oh let us not linger, 0
# oh fly  let us fly  for we must, 0
# in terror she spoke letting sink her, 0
# wings until they trailed in the dust , 0
# in agony sobbed letting sink her, 0
# plumes till they trailed in the dust , 0
# till they sorrowfully trailed in the dust, 0
# i replied  this is nothing but dreaming, 0
# let us on by this tremulous light, 0
# let us bathe in this crystalline light, 0
# its sybilic splendor is beaming, 0
# with hope and in beauty tonight , 0
# see  it flickers up the sky through the night, 0
# ah we safely may trust to its gleaming, 0
# and be sure it will lead us aright , 0
# we safely may trust to a gleaming, 0
# that cannot but guide us aright, 0
# since it flickers up to heaven through the night, 0
# thus i pacified psyche and kissed her, 0
# and tempted her out of her gloom , 0
# and conquered her scruples and gloom, 0
# and we passed to the end of the vista, 0
# but were stopped by the door of a tomb , 0
# by the door of a legended tomb, 0
# and i said  what is written sweet sister, 0
# on the door of this legended tomb, 0
# she replied  ulalume  ulalume , 0
# ‘tis the vault of thy lost ulalume, 0
# then my heart it grew ashen and sober, 0
# as the leaves that were crisped and sere , 0
# as the leaves that were withering and sere, 0
# and i cried  it was surely october, 0
# on this very night of last year, 0
# that i journeyed  i journeyed down here , 0
# that i brought a dread burden down here, 0
# on this night of all nights in the year, 0
# ah what demon has tempted me here, 0
# well i know now this dim lake of auber , 0
# this misty mid region of weir , 0
# well i know now this dank tarn of auber , 0
# this ghoulhaunted woodland of weir, 0
# wreathed in myrtle my sword ill conceal, 0
# like those champions devoted and brave, 0
# when they plunged in the tyrant their steel, 0
# and to athens deliverance gave, 0
# beloved heroes your deathless souls roam, 0
# in the joy breathing isles of the blest, 0
# where the mighty of old have their home , 0
# where achilles and diomed rest, 0
# in fresh myrtle my blade ill entwine, 0
# like harmodious the gallant and good, 0
# when he made at the tutelar shrine, 0
# a libation of tyrannys blood, 0
# ye deliverers of athens from shame, 0
# ye avengers of libertys wrongs, 0
# endless ages shall cherish your fame, 0
# embalmed in their echoing songs, 0
# of all who hail thy presence as the morning, 0
# of all to whom thine absence is the night, 0
# the blotting utterly from out high heaven, 0
# the sacred sun of all who weeping bless thee, 0
# hourly for hope for life ah above all, 0
# for the resurrection of deepburied faith, 0
# in truth in virtue in humanity, 0
# of all who on despairs unhallowed bed, 0
# lying down to die have suddenly arisen, 0
# at thy softmurmured words let there be light, 0
# at the softmurmured words that were fulfilled, 0
# in the seraphic glancing of thine eyes, 0
# of all who owe thee most whose gratitude, 0
# nearest resembles worship oh remember, 0
# the truest the most fervently devoted, 0
# and think that these weak lines are written by him, 0
# by him who as he pens them thrills to think, 0
# his spirit is communing with an angels, 0
# thou wouldst be loved then let thy heart, 0
# from its present pathway part not, 0
# being everything which now thou art, 0
# be nothing which thou art not, 0
# so with the world thy gentle ways, 0
# thy grace thy more than beauty, 0
# shall be an endless theme of praise, 0
# and love a simple duty, 0
# when from your gems of thought i turn, 0
# to those pure orbs your heart to learn, 0
# i scarce know which to prize most high, 0
# the bright idea or the bright deareye, 0
# of all who hail thy presence as the morning, 0
# of all to whom thine absence is the night, 0
# the blotting utterly from out high heaven, 0
# the sacred sun of all who weeping bless thee, 0
# hourly for hope for life ah above all, 0
# for the resurrection of deepburied faith, 0
# in truth in virtue in humanity, 0
# of all who on despairs unhallowed bed, 0
# lying down to die have suddenly arisen, 0
# at thy softmurmured words let there be light, 0
# at the softmurmured words that were fulfilled, 0
# in the seraphic glancing of thine eyes, 0
# of all who owe thee most whose gratitude, 0
# nearest resembles worship oh remember, 0
# the truest the most fervently devoted, 0
# and think that these weak lines are written by him, 0
# by him who as he pens them thrills to think, 0
# his spirit is communing with an angels, 0
# fair isle that from the fairest of all flowers, 0
# thy gentlest of all gentle names dost take, 0
# how many memories of what radiant hours, 0
# at sight of thee and thine at once awake, 0
# how many scenes of what departed bliss, 0
# how many thoughts of what entombed hopes, 0
# how many visions of a maiden that is, 0
# no more no more upon thy verdant slopes, 0
# no more alas that magical sad sound, 0
# transforming all thy charms shall please no more, 0
# thy memory no more accursed ground, 0
# henceforth i hold thy flowerenameled shore, 0
# o hyacinthine isle o purple zante, 0
# isola doro fior di levante, 0
# o i care not that my earthly lot, 0
# hath little of earth in it, 0
# that years of love have been forgot, 0
# in the fever of a minute, 0
# i heed not that the desolate, 0
# are happier sweet than i, 0
# but that you meddle with my fate, 0
# who am a passer by, 0
# it is not that my founts of bliss, 0
# are gushing strange with tears, 0
# or that the thrill of a single kiss, 0
# hath palsied many years, 0
# tis not that the flowers of twenty springs, 0
# which have witherd as they rose, 0
# lie dead on my heartstrings, 0
# with the weight of an age of snows, 0
# not that the grass o may it thrive, 0
# on my grave is growing or grown, 0
# but that while i am dead yet alive, 0
# i cannot be lady alone, 0
# sancta maria turn thine eyes , 0
# upon the sinners sacrifice, 0
# of fervent prayer and humble love, 0
# from thy holy throne above, 0
# at morn  at noon  at twilight dim , 0
# maria thou hast heard my hymn, 0
# in joy and wo  in good and ill , 0
# mother of god be with me still, 0
# when the hours flew brightly by, 0
# and not a cloud obscured the sky, 0
# my soul lest it should truant be, 0
# thy grace did guide to thine and thee, 0
# now when storms of fate oercast, 0
# darkly my present and my past, 0
# let my future radiant shine, 0
# with sweet hopes of thee and thine, 0
# the bells ah the bells, 0
# the little silver bells, 0
# how fairylike a melody there floats, 0
# from their throats, 0
# from their merry little throats, 0
# from the silver tinkling throats, 0
# of the bells bells bells, 0
# of the bells, 0
# the bells ah the bells, 0
# the heavy iron bells, 0
# how horrible a monody there floats, 0
# from their throats, 0
# from their deeptoned throats, 0
# from their melancholy throats, 0
# how i shudder at the notes, 0
# of the bells bells bells, 0
# of the bells, 0
# how often we forget all time when lone, 0
# admiring natures universal throne, 0
# her woods her wilds her mountains the intense, 0
# reply of hers to our intelligence, 0
# in youth have i known one with whom the earth, 0
# in secret communing held as he with it, 0
# in daylight and in beauty from his birth, 0
# whose fervid flickering torch of life was lit, 0
# from the sun and stars whence he had drawn forth, 0
# a passionate light such for his spirit was fit, 0
# and yet that spirit knew not in the hour, 0
# of its own fervor what had oer it power, 0
# perhaps it may be that my mind is wrought, 0
# to a fever by the moonbeam that hangs oer, 0
# but i will half believe that wild light fraught, 0
# with more of sovereignty than ancient lore, 0
# hath ever told or is it of a thought, 0
# the unembodied essence and no more, 0
# that with a quickening spell doth oer us pass, 0
# as dew of the nighttime oer the summer grass, 0
# doth oer us pass when as th expanding eye, 0
# to the loved object so the tear to the lid, 0
# will start which lately slept in apathy, 0
# and yet it need not be that object hid, 0
# from us in life but common which doth lie, 0
# each hour before us but then only bid, 0
# with a strange sound as of a harpstring broken, 0
# to awake us tis a symbol and a token, 0
# of what in other worlds shall be and given, 0
# in beauty by our god to those alone, 0
# who otherwise would fall from life and heaven, 0
# drawn by their hearts passion and that tone, 0
# that high tone of the spirit which hath striven, 0
# tho not with faith with godliness whose throne, 0
# with desperate energy t hath beaten down, 0
# wearing its own deep feeling as a crown, 0
# not long ago the writer of these lines, 0
# in the mad pride of intellectuality, 0
# maintained the power of words denied that ever, 0
# a thought arose within the human brain, 0
# beyond the utterance of the human tongue, 0
# and now as if in mockery of that boast, 0
# two words two foreign soft dissyllables, 0
# italian tones made only to be murmured, 0
# by angels dreaming in the moonlit dew, 0
# that hangs like chains of pearl on hermon hill, 0
# have stirred from out the abysses of his heart, 0
# unthoughtlike thoughts that are the souls of thought, 0
# richer far wilder far diviner visions, 0
# than even seraph harper israfel, 0
# who has the sweetest voice of all gods creatures, 0
# could hope to utter and i my spells are broken, 0
# the pen falls powerless from my shivering hand, 0
# with thy dear name as text though bidden by thee, 0
# i cannot write i cannot speak or think, 0
# alas i cannot feel for tis not feeling, 0
# this standing motionless upon the golden, 0
# threshold of the wideopen gate of dreams, 0
# gazing entranced adown the gorgeous vista, 0
# and thrilling as i see upon the right, 0
# upon the left and all the way along, 0
# amid empurpled vapors far away, 0
# to where the prospect terminates thee only, 0
# beloved amid the earnest woes, 0
# that crowd around my earthly path, 0
# drear path alas where grows, 0
# not even one lonely rose, 0
# my soul at least a solace hath, 0
# in dreams of thee and therein knows, 0
# an eden of bland repose, 0
# and thus thy memory is to me, 0
# like some enchanted faroff isle, 0
# in some tumultuous sea, 0
# some ocean throbbing far and free, 0
# with storms but where meanwhile, 0
# serenest skies continually, 0
# just oer that one bright island smile, 0
# i saw thee once once only years ago, 0
# i must not say how many but not many, 0
# it was a july midnight and from out, 0
# a fullorbed moon that like thine own soul soaring, 0
# sought a precipitate pathway up through heaven, 0
# there fell a silverysilken veil of light, 0
# with quietude and sultriness and slumber, 0
# upon the upturned faces of a thousand, 0
# roses that grew in an enchanted garden, 0
# where no wind dared to stir unless on tiptoe, 0
# fell on the upturnd faces of these roses, 0
# that gave out in return for the lovelight, 0
# their odorous souls in an ecstatic death, 0
# fell on the upturnd faces of these roses, 0
# that smiled and died in this parterre enchanted, 0
# by thee and by the poetry of thy presence, 0
# clad all in white upon a violet bank, 0
# i saw thee half reclining while the moon, 0
# fell on the upturnd faces of the roses, 0
# and on thine own upturnd alas in sorrow, 0
# was it not fate that on this july midnight, 0
# was it not fate whose name is also sorrow, 0
# that bade me pause before that gardengate, 0
# to breathe the incense of those slumbering roses, 0
# no footstep stirred the hated world an slept, 0
# save only thee and me oh heaven oh god, 0
# how my heart beats in coupling those two words, 0
# save only thee and me i paused i looked, 0
# and in an instant all things disappeared, 0
# ah bear in mind this garden was enchanted, 0
# the pearly lustre of the moon went out, 0
# the mossy banks and the meandering paths, 0
# the happy flowers and the repining trees, 0
# were seen no more the very roses odors, 0
# died in the arms of the adoring airs, 0
# all all expired save thee save less than thou, 0
# save only the divine light in thine eyes, 0
# save but the soul in thine uplifted eyes, 0
# i saw but them they were the world to me, 0
# i saw but them saw only them for hours, 0
# saw only them until the moon went down, 0
# what wild hearthistories seemed to he enwritten, 0
# upon those crystalline celestial spheres, 0
# how dark a woe yet how sublime a hope, 0
# how silently serene a sea of pride, 0
# how daring an ambition yet how deep, 0
# how fathomless a capacity for love, 0
# but now at length dear dian sank from sight, 0
# into a western couch of thundercloud, 0
# and thou a ghost amid the entombing trees, 0
# didst glide away only thine eyes remained, 0
# they would not go they never yet have gone, 0
# lighting my lonely pathway home that night, 0
# they have not left me as my hopes have since, 0
# they follow me they lead me through the years, 0
# they are my ministers yet i their slave, 0
# their office is to illumine and enkindle, 0
# my duty to be saved by their bright light, 0
# and purified in their electric fire, 0
# and sanctified in their elysian fire, 0
# they fill my soul with beauty which is hope, 0
# and are far up in heaven the stars i kneel to, 0
# in the sad silent watches of my night, 0
# while even in the meridian glare of day, 0
# i see them still two sweetly scintillant, 0
# venuses unextinguished by the sun, 0
# the bowers whereat in dreams i see, 0
# the wantonest singing birds, 0
# are lips and all thy melody, 0
# of lipbegotten words, 0
# thine eyes in heaven of heart enshrined, 0
# then desolately fall, 0
# o god on my funereal mind, 0
# like starlight on a pall, 0
# thy heart thy heart i wake and sigh, 0
# and sleep to dream till day, 0
# of the truth that gold can never buy, 0
# of the baubles that it may, 0
# in heaven a spirit doth dwell, 0
# whose heartstrings are a lute, 0
# none sing so wildly well, 0
# as the angel israfel, 0
# and the giddy stars so legends tell, 0
# ceasing their hymns attend the spell, 0
# of his voice all mute, 0
# tottering above, 0
# in her highest noon, 0
# the enamored moon, 0
# blushes with love, 0
# while to listen the red levin, 0
# with the rapid pleiads even, 0
# which were seven, 0
# pauses in heaven, 0
# and they say the starry choir, 0
# and the other listening things, 0
# that israfelis fire, 0
# is owing to that lyre, 0
# by which he sits and sings, 0
# the trembling living wire, 0
# of those unusual strings, 0
# but the skies that angel trod, 0
# where deep thoughts are a duty, 0
# where loves a grownup god, 0
# where the houri glances are, 0
# imbued with all the beauty, 0
# which we worship in a star, 0
# therefore thou art not wrong, 0
# israfeli who despisest, 0
# an unimpassioned song, 0
# to thee the laurels belong, 0
# best bard because the wisest, 0
# merrily live and long, 0
# the ecstasies above, 0
# with thy burning measures suit, 0
# thy grief thy joy thy hate thy love, 0
# with the fervor of thy lute, 0
# well may the stars be mute, 0
# yes heaven is thine but this, 0
# is a world of sweets and sours, 0
# our flowers are merely flowers, 0
# and the shadow of thy perfect bliss, 0
# is the sunshine of ours, 0
# if i could dwell, 0
# where israfel, 0
# hath dwelt and he where i, 0
# he might not sing so wildly well, 0
# a mortal melody, 0
# while a bolder note than this might swell, 0
# from my lyre within the sky, 0
# science true daughter of old time thou art, 0
# who alterest all things with thy peering eyes, 0
# why preyest thou thus upon the poets heart, 0
# vulture whose wings are dull realities, 0
# how should he love thee or how deem thee wise, 0
# who wouldst not leave him in his wandering, 0
# to seek for treasure in the jewelled skies, 0
# albeit he soared with an undaunted wing, 0
# hast thou not dragged diana from her car, 0
# and driven the hamadryad from the wood, 0
# to seek a shelter in some happier star, 0
# hast thou not torn the naiad from her flood, 0
# the elfin from the green grass and from me, 0
# the summer dream beneath the tamarind tree, 0
# ill tell you a plan for gaining wealth, 0
# better than banking trade or leases, 0
# take a bank note and fold it up, 0
# and then you will find your money in creases, 0
# this wonderful plan without danger or loss, 0
# keeps your cash in your hands where nothing can trouble it, 0
# and every time that you fold it across, 0
# tis as plain as the light of the day that you double it, 0
# the skies they were ashen and sober, 0
# the leaves they were crisped and sere, 0
# the leaves they were withering and sere, 0
# it was night in the lonesome october, 0
# of my most immemorial year, 0
# it was hard by the dim lake of auber, 0
# in the misty mid region of weir, 0
# it was down by the dank tarn of auber, 0
# in the ghoulhaunted woodland of weir, 0
# here once through an alley titanic, 0
# of cypress i roamed with my soul, 0
# of cypress with psyche my soul, 0
# there were days when my heart was volcanic, 0
# as the scoriac rivers that roll, 0
# as the lavas that restlessly roll, 0
# their sulphurous currents down yaanek, 0
# in the ultimate climes of the pole, 0
# that groan as they roll down mount yaanek, 0
# in the realms of the boreal pole, 0
# our talk had been serious and sober, 0
# but our thoughts they were palsied and sere, 0
# our memories were treacherous and sere, 0
# for we knew not the month was october, 0
# and we marked not the night of the year, 0
# ah night of all nights in the year, 0
# we noted not the dim lake of auber, 0
# though once we had journeyed down here, 0
# remembered not the dank tarn of auber, 0
# nor the ghoulhaunted woodland of weir, 0
# and now as the night was senescent, 0
# and stardials pointed to morn, 0
# as the stardials hinted of morn, 0
# at the end of our path a liquescent, 0
# and nebulous lustre was born, 0
# out of which a miraculous crescent, 0
# arose with a duplicate horn, 0
# astartes bediamonded crescent, 0
# distinct with its duplicate horn, 0
# and i said she is warmer than dian, 0
# she rolls through an ether of sighs, 0
# she revels in a region of sighs, 0
# she has seen that the tears are not dry on, 0
# these cheeks where the worm never dies, 0
# and has come past the stars of the lion, 0
# to point us the path to the skies, 0
# to the lethean peace of the skies, 0
# come up in despite of the lion, 0
# to shine on us with her bright eyes, 0
# come up through the lair of the lion, 0
# with love in her luminous eyes, 0
# but psyche uplifting her finger, 0
# said sadly this star i mistrust, 0
# her pallor i strangely mistrust, 0
# oh hasten oh let us not linger, 0
# oh fly let us fly for we must, 0
# in terror she spoke letting sink her, 0
# wings until they trailed in the dust, 0
# in agony sobbed letting sink her, 0
# plumes till they trailed in the dust, 0
# till they sorrowfully trailed in the dust, 0
# i replied this is nothing but dreaming, 0
# let us on by this tremulous light, 0
# let us bathe in this crystalline light, 0
# its sybilic splendor is beaming, 0
# with hope and in beauty tonight, 0
# see it flickers up the sky through the night, 0
# ah we safely may trust to its gleaming, 0
# and be sure it will lead us aright, 0
# we safely may trust to a gleaming, 0
# that cannot but guide us aright, 0
# since it flickers up to heaven through the night, 0
# thus i pacified psyche and kissed her, 0
# and tempted her out of her gloom, 0
# and conquered her scruples and gloom, 0
# and we passed to the end of the vista, 0
# but were stopped by the door of a tomb, 0
# by the door of a legended tomb, 0
# and i said what is written sweet sister, 0
# on the door of this legended tomb, 0
# she replied ulalume ulalume, 0
# tis the vault of thy lost ulalume, 0
# then my heart it grew ashen and sober, 0
# as the leaves that were crisped and sere, 0
# as the leaves that were withering and sere, 0
# and i cried it was surely october, 0
# on this very night of last year, 0
# that i journeyed i journeyed down here, 0
# that i brought a dread burden down here, 0
# on this night of all nights in the year, 0
# ah what demon has tempted me here, 0
# well i know now this dim lake of auber, 0
# this misty mid region of weir, 0
# well i know now this dank tarn of auber, 0
# this ghoulhaunted woodland of weir, 0
# how often we forget all time when lone, 0
# admiring natures universal throne, 0
# her woods  her winds  her mountains  the intense, 0
# reply of hers to our intelligence, 0
# in youth i have known one with whom the earth, 0
# in secret communing held  as he with it, 0
# in daylight and in beauty from his birth, 0
# whose fervid flickering torch of life was lit, 0
# from the sun and stars whence he had drawn forth, 0
# a passionate light  such for his spirit was fit , 0
# and yet that spirit knew  not in the hour, 0
# of its own fervour  what had oer it power, 0
# perhaps it may be that my mind is wrought, 0
# to a fever by the moonbeam that hangs oer, 0
# but i will half believe that wild light fraught, 0
# with more of sovereignty than ancient lore, 0
# hath ever told  or is it of a thought, 0
# the unembodied essence and no more, 0
# that with a quickening spell doth oer us pass, 0
# as dew of the night time oer the summer grass, 0
# doth oer us pass when as th expanding eye, 0
# to the loved object  so the tear to the lid, 0
# will start which lately slept in apathy, 0
# and yet it need not be  that object hid, 0
# from us in life  but common  which doth lie, 0
# each hour before us  but then only bid, 0
# with a strange sound as of a harpstring broken, 0
# t awake us  tis a symbol and a token , 0
# of what in other worlds shall be  and given, 0
# in beauty by our god to those alone, 0
# who otherwise would fall from life and heaven, 0
# drawn by their hearts passion and that tone, 0
# that high tone of the spirit which hath striven, 0
# though not with faith  with godliness  whose throne, 0
# with desperate energy t hath beaten down, 0
# wearing its own deep feeling as a crown, 0
# tis said that when, 0
# the hands of men, 0
# tamed this primeval wood, 0
# and hoary trees with groans of woe, 0
# like warriors by an unknown foe, 0
# were in their strength subdued, 0
# the virgin earth gave instant birth, 0
# to springs that neer did flow, 0
# that in the sun did rivulets run, 0
# and all around rare flowers did blow, 0
# the wild rose pale perfumed the gale, 0
# and the queenly lily adown the dale, 0
# whom the sun and the dew, 0
# and the winds did woo, 0
# with the gourd and the grape luxuriant grew, 0
# so when in tears, 0
# the love of years, 0
# is wasted like the snow, 0
# and the fine fibrils of its life, 0
# by the rude wrong of instant strife, 0
# are broken at a blow, 0
# within the heart, 0
# do springs upstart, 0
# of which it doth now know, 0
# and strange sweet dreams, 0
# like silent streams, 0
# that from new fountains overflow, 0
# with the earlier tide, 0
# of rivers glide, 0
# deep in the heart whose hope has died, 0
# quenching the fires its ashes hide, 0
# its ashes whence will spring and grow, 0
# sweet flowers ere long, 0
# the rare and radiant flowers of song, 0
# in the greenest of our valleys, 0
# by good angels tenanted, 0
# once fair and stately palace , 0
# radiant palace reared its head, 0
# in the monarch thoughts dominion , 0
# it stood there, 0
# never seraph spread a pinion, 0
# over fabric half so fair, 0
# banners yellow glorious golden, 0
# on its roof did float and flow, 0
# this all this was in the olden, 0
# time long ago, 0
# and every gentle air that dallied, 0
# in that sweet day, 0
# along the ramparts plumed and pallid, 0
# a winged odour went away, 0
# wanderers in that happy valley, 0
# through two luminous windows saw, 0
# spirits moving musically, 0
# to a lutes welltuned law, 0
# round about a throne where sitting, 0
# porphyrogene, 0
# in state his glory well befitting, 0
# the ruler of the realm was seen, 0
# and all with pearl and ruby glowing, 0
# was the fair palace door, 0
# through which came flowing flowing flowing, 0
# and sparkling evermore, 0
# a troop of echoes whose sweet duty, 0
# was but to sing, 0
# in voices of surpassing beauty, 0
# the wit and wisdom of their king, 0
# but evil things in robes of sorrow, 0
# assailed the monarchs high estate, 0
# ah let us mourn for never morrow, 0
# shall dawn upon him desolate, 0
# and round about his home the glory, 0
# that blushed and bloomed, 0
# is but a dimremembered story, 0
# of the old time entombed, 0
# and travellers now within that valley, 0
# through the redlitten windows see, 0
# vast forms that move fantastically, 0
# to a discordant melody, 0
# while like a rapid ghastly river, 0
# through the pale door, 0
# a hideous throng rush out forever, 0
# and laugh but smile no more, 0
# two roads diverged in a yellow wood, 1
# and sorry i could not travel both, 1
# and be one traveler long i stood, 1
# and looked down one as far as i could, 1
# to where it bent in the undergrowth, 1
# then took the other as just as fair, 1
# and having perhaps the better claim, 1
# because it was grassy and wanted wear, 1
# though as for that the passing there, 1
# had worn them really about the same, 1
# and both that morning equally lay, 1
# in leaves no step had trodden black, 1
# oh i kept the first for another day, 1
# yet knowing how way leads on to way, 1
# i doubted if i should ever come back, 1
# i shall be telling this with a sigh, 1
# somewhere ages and ages hence, 1
# two roads diverged in a wood and i, 1
# i took the one less traveled by, 1
# and that has made all the difference, 1
# whose woods these are i think i know, 1
# his house is in the village though, 1
# he will not see me stopping here, 1
# to watch his woods fill up with snow, 1
# my little horse must think it queer, 1
# to stop without a farmhouse near, 1
# between the woods and frozen lake, 1
# the darkest evening of the year, 1
# he gives his harness bells a shake, 1
# to ask if there is some mistake, 1
# the only other sounds the sweep, 1
# of easy wind and downy flake, 1
# the woods are lovely dark and deep, 1
# but i have promises to keep, 1
# and miles to go before i sleep, 1
# and miles to go before i sleep, 1
# some say the world will end in fire, 1
# some say in ice, 1
# from what ive tasted of desire, 1
# i hold with those who favor fire, 1
# but if it had to perish twice, 1
# i think i know enough of hate, 1
# to say that for destruction ice, 1
# is also great, 1
# and would suffice, 1
# natures first green is gold, 1
# her hardest hue to hold, 1
# her early leafs a flower, 1
# but only so an hour, 1
# then leaf subsides to leaf, 1
# so eden sank to grief, 1
# so dawn goes down to day, 1
# nothing gold can stay, 1
# i have been one acquainted with the night, 1
# i have walked out in rain  and back in rain, 1
# i have outwalked the furthest city light, 1
# i have looked down the saddest city lane, 1
# i have passed by the watchman on his beat, 1
# and dropped my eyes unwilling to explain, 1
# i have stood still and stopped the sound of feet, 1
# when far away an interrupted cry, 1
# came over houses from another street, 1
# but not to call me back or say goodbye, 1
# and further still at an unearthly height, 1
# one luminary clock against the sky, 1
# proclaimed the time was neither wrong nor right, 1
# i have been one acquainted with the night, 1
# when i go up through the mowing field, 1
# the headless aftermath, 1
# smoothlaid like thatch with the heavy dew, 1
# half closes the garden path, 1
# and when i come to the garden ground, 1
# the whir of sober birds, 1
# up from the tangle of withered weeds, 1
# is sadder than any words, 1
# a tree beside the wall stands bare, 1
# but a leaf that lingered brown, 1
# disturbed i doubt not by my thought, 1
# comes softly rattling down, 1
# i end not far from my going forth, 1
# by picking the faded blue, 1
# of the last remaining aster flower, 1
# to carry again to you, 1
# a voice said look me in the stars, 1
# and tell me truly men of earth, 1
# if all the soulandbody scars, 1
# were not too much to pay for birth, 1
# to think to know the country and now know, 1
# the hillside on the day the sun lets go, 1
# ten million silver lizards out of snow, 1
# as often as ive seen it done before, 1
# i cant pretend to tell the way its done, 1
# it looks as if some magic of the sun, 1
# lifted the rug that bred them on the floor, 1
# and the light breaking on them made them run, 1
# but if i though to stop the wet stampede, 1
# and caught one silver lizard by the tail, 1
# and put my foot on one without avail, 1
# and threw myself wetelbowed and wetkneed, 1
# in front of twenty others wriggling speed, 1
# in the confusion of them all aglitter, 1
# and birds that joined in the excited fun, 1
# by doubling and redoubling song and twitter, 1
# i have no doubt id end by holding none, 1
# it takes the moon for this the suns a wizard, 1
# by all i tell but sos the moon a witch, 1
# from the high west she makes a gentle cast, 1
# and suddenly without a jerk or twitch, 1
# she has her speel on every single lizard, 1
# i fancied when i looked at six oclock, 1
# the swarm still ran and scuttled just as fast, 1
# the moon was waiting for her chill effect, 1
# i looked at nine the swarm was turned to rock, 1
# in every lifelike posture of the swarm, 1
# transfixed on mountain slopes almost erect, 1
# across each other and side by side they lay, 1
# the spell that so could hold them as they were, 1
# was wrought through trees without a breath of storm, 1
# to make a leaf if there had been one stir, 1
# one lizard at the end of every ray, 1
# the thought of my attempting such a stray, 1
# once on the kind of day called weather breeder, 1
# when the heat slowly hazes and the sun, 1
# by its own power seems to be undone, 1
# i was half boring through half climbing through, 1
# a swamp of cedar choked with oil of cedar, 1
# and scurf of plants and weary and overheated, 1
# and sorry i ever left the road i knew, 1
# i paused and rested on a sort of hook, 1
# that had me by the coat as good as seated, 1
# and since there was no other way to look, 1
# looked up toward heaven and there against the blue, 1
# stood over me a resurrected tree, 1
# a tree that had been down and raised again—, 1
# a barkless spectre he had halted too, 1
# as if for fear of treading upon me, 1
# i saw the strange position of his hands—, 1
# up at his shoulders dragging yellow strands, 1
# of wire with something in it from men to men, 1
# you here i said where arent you nowadays, 1
# and whats the news you carry—if you know, 1
# and tell me where youre off for—montreal, 1
# me im not off for anywhere at all, 1
# sometimes i wander out of beaten ways, 1
# half looking for the orchid calypso, 1
# brown lived at such a lofty farm, 1
# that everyone for miles could see, 1
# his lantern when he did his chores, 1
# in winter after halfpast three, 1
# and many must have seen him make, 1
# his wild descent from there one night, 1
# cross lots cross walls cross everything, 1
# describing rings of lantern light, 1
# between the house and barn the gale, 1
# got him by something he had on, 1
# and blew him out on the icy crust, 1
# that cased the world and he was gone, 1
# walls were all buried trees were few, 1
# he saw no stay unless he stove, 1
# a hole in somewhere with his heel, 1
# but though repeatedly he strove, 1
# and stamped and said things to himself, 1
# and sometimes something seemed to yield, 1
# he gained no foothold but pursued, 1
# his journey down from field to field, 1
# sometimes he came with arms outspread, 1
# like wings revolving in the scene, 1
# upon his longer axis and, 1
# with no small dignity of mien, 1
# faster or slower as he chanced, 1
# sitting or standing as he chose, 1
# according as he feared to risk, 1
# his neck or thought to spare his clothes, 1
# he never let the lantern drop, 1
# and some exclaimed who saw afar, 1
# the figures he described with it, 1
# i wonder what those signals are, 1
# brown makes at such an hour of night, 1
# hes celebrating something strange, 1
# i wonder if hes sold his farm, 1
# or been made master of the grange, 1
# he reeled he lurched he bobbed he checked, 1
# he fell and made the lantern rattle, 1
# but saved the light from going out, 1
# so halfway down he fought the battle, 1
# incredulous of his own bad luck, 1
# and then becoming reconciled, 1
# to everything he gave it up, 1
# and came down like a coasting child, 1
# well—i—be— that was all he said, 1
# as standing in the river road, 1
# he looked back up the slippery slope, 1
# two miles it was to his abode, 1
# sometimes as an authority, 1
# on motorcars im asked if i, 1
# should say our stock was petered out, 1
# and this is my sincere reply, 1
# yankees are what they always were, 1
# dont think brown ever gave up hope, 1
# of getting home again because, 1
# he couldnt climb that slippery slope, 1
# or even thought of standing there, 1
# until the january thaw, 1
# should take the polish off the crust, 1
# he bowed with grace to natural law, 1
# and then went round it on his feet, 1
# after the manner of our stock, 1
# not much concerned for those to whom, 1
# at that particular time oclock, 1
# it must have looked as if the course, 1
# he steered was really straight away, 1
# from that which he was headed for—, 1
# not much concerned for them i say, 1
# no more so than became a man—, 1
# and politician at odd seasons, 1
# ive kept brown standing in the cold, 1
# while i invested him with reasons, 1
# but now he snapped his eyes three times, 1
# then shook his lantern saying iles, 1
# bout out and took the long way home, 1
# by road a matter of several miles, 1
# now that theyve got it settled whose i be, 1
# im going to tell them something they wont like, 1
# theyve got it settled wrong and i can prove it, 1
# flattered i must be to have two towns fighting, 1
# to make a present of me to each other, 1
# they dont dispose me either one of them, 1
# to spare them any trouble double troubles, 1
# always the witchs motto anyway, 1
# ill double theirs for both of them you watch me, 1
# theyll find theyve got the whole thing to do over, 1
# that is if facts is what they want to go by, 1
# they set a lot now dont they by a record, 1
# of arthur amys having once been up, 1
# for hog reeve in march meeting here in warren, 1
# i could have told them any time this twelvemonth, 1
# the arthur amy i was married to, 1
# couldnt have been the one they say was up, 1
# in warren at march meeting for the reason, 1
# he want but fifteen at the time they say, 1
# the arthur amy i was married to, 1
# voted the only times he ever voted, 1
# which wasnt many in the town of wentworth, 1
# one of the times was when twas in the warrant, 1
# to see if the town wanted to take over, 1
# the tote road to our clearing where we lived, 1
# ill tell you whod remember heman lapish, 1
# their arthur amy was the father of mine, 1
# so now theyve dragged it through the law courts once, 1
# i guess theyd better drag it through again, 1
# wentworth and warrens both good towns to live in, 1
# only i happen to prefer to live, 1
# in wentworth from now on and when alls said, 1
# rights right and the temptation to do right, 1
# when i can hurt someone by doing it, 1
# has always been too much for me it has, 1
# i know of some folks thatd be set up, 1
# at having in their town a noted witch, 1
# but most would have to think of the expense, 1
# that even i would be they ought to know, 1
# that as a witch id often milk a bat, 1
# and thatd be enough to last for days, 1
# itd make my position stronger i think, 1
# if i was to consent to give some sign, 1
# to make it surer that i was a witch, 1
# it want no sign i spose when mallice huse, 1
# said that i took him out in his old age, 1
# and rode all over everything on him, 1
# until id had him worn to skin and bones, 1
# and if id left him hitched unblanketed, 1
# in front of one town hall id left him hitched, 1
# in front of every one in grafton county, 1
# some cried shame on me not to blanket him, 1
# the poor old man it would have been all right, 1
# if some one hadnt said to gnaw the posts, 1
# he stood beside and leave his trade mark on them, 1
# so they could recognize them not a post, 1
# that they could hear tell of was scarified, 1
# they made him keep on gnawing till he whined, 1
# then that same smarty someone said to look, 1
# hed bet huse was a cribber and had gnawed, 1
# the crib he slept in and as sures youre born, 1
# they found hed gnawed the four posts of his bed, 1
# all four of them to splinters what did that prove, 1
# not that he hadnt gnawed the hitching posts, 1
# he said he had besides because a horse, 1
# gnaws in the stable aint no proof to me, 1
# he dont gnaw trees and posts and fences too, 1
# but everybody took it for proof, 1
# i was a strapping girl of twenty then, 1
# the smarty someone who spoiled everything, 1
# was arthur amy you know who he was, 1
# that was the way he started courting me, 1
# he never said much after we were married, 1
# but i mistrusted he was none too proud, 1
# of having interfered in the huse business, 1
# i guess he found he got more out of me, 1
# by having me a witch or something happened, 1
# to turn him round he got to saying things, 1
# to undo what hed done and make it right, 1
# like no she aint come back from kiting yet, 1
# last night was one of her nights out shes kiting, 1
# she thinks when the wind makes a night of it, 1
# she might as well herself but he liked best, 1
# to let on he was plagued to death with me, 1
# if anyone had seen me coming home, 1
# over the ridgepole stride of a broomstick, 1
# as often as he had in the tail of the night, 1
# he guessed theyd know what he had to put up with, 1
# well i showed arthur amy signs enough, 1
# off from the house as far as we could keep, 1
# and from barn smells you cant wash out of ploughed ground, 1
# with all the rain and snow of seven years, 1
# and i dont mean just skulls of rogers rangers, 1
# on moosilauke but woman signs to man, 1
# only bewitched so i would last him longer, 1
# up where the trees grow short the mosses tall, 1
# i made him gather me wet snow berries, 1
# on slippery rocks beside a waterfall, 1
# i made him do it for me in the dark, 1
# and he liked everything i made him do, 1
# i hope if he is where he sees me now, 1
# hes so far off he cant see what ive come to, 1
# you can come down from everything to nothing, 1
# all is if id aknown when i was young, 1
# and full of it that this would be the end, 1
# it doesnt seem as if id had the courage, 1
# to make so free and kick up in folks faces, 1
# i might have but it doesnt seem as if, 1
# old davis owned a solid mica mountain, 1
# in dalton that would someday make his fortune, 1
# thered been some boston people out to see it, 1
# and experts said that deep down in the mountain, 1
# the mica sheets were big as plateglass windows, 1
# hed like to take me there and show it to me, 1
# ill tell you what you show me you remember, 1
# you said you knew the place where once on kinsman, 1
# the early mormons made a settlement, 1
# and built a stone baptismal font outdoors, 1
# but smith or someone called them off the mountain, 1
# to go west to a worse fight with the desert, 1
# you said youd seen the stone baptismal font, 1
# well take me there, 1
# someday i will, 1
# today, 1
# huh that old bathtub what is that to see, 1
# lets talk about it, 1
# lets go see the place, 1
# to shut you up ill tell you what ill do, 1
# ill find that fountain if it takes all summer, 1
# and both of our united strengths to do it, 1
# youve lost it then, 1
# not so but i can find it, 1
# no doubt its grown up some to woods around it, 1
# the mountain may have shifted since i saw it, 1
# in eightyfive, 1
# as long ago as that, 1
# if i remember rightly it had sprung, 1
# a leak and emptied then and forty years, 1
# can do a good deal to bad masonry, 1
# you wont see any mormon swimming in it, 1
# but you have said it and were off to find it, 1
# old as i am im going to let myself, 1
# be dragged by you all over everywhere , 1
# i thought you were a guide, 1
# i am a guide, 1
# and thats why i cant decently refuse you, 1
# we made a day of it out of the world, 1
# ascending to descend to reascend, 1
# the old man seriously took his bearings, 1
# and spoke his doubts in every open place, 1
# we came out on a lookoff where we faced, 1
# a cliff and on the cliff a bottle painted, 1
# or stained by vegetation from above, 1
# a likeness to surprise the thrilly tourist, 1
# well if i havent brought you to the fountain, 1
# at least ive brought you to the famous bottle, 1
# i wont accept the substitute its empty, 1
# sos everything, 1
# i want my fountain, 1
# i guess youd find the fountain just as empty, 1
# and anyway this tells me where i am, 1
# hadnt you long suspected where you were, 1
# you mean miles from that mormon settlement, 1
# look here you treat your guide with due respect, 1
# if you dont want to spend the night outdoors, 1
# i vow we must be near the place from where, 1
# the two converging slides the avalanches, 1
# on marshall look like donkeys ears, 1
# we may as well see that and save the day, 1
# dont donkeys ears suggest we shake our own, 1
# for gods sake arent you fond of viewing nature, 1
# you dont like nature all you like is books, 1
# what signify a donkeys cars and bottle, 1
# however natural give you your books, 1
# well then right here is where i show you books, 1
# come straight down off this mountain just as fast, 1
# as we can fall and keep abouncing on our feet, 1
# its hell for knees unless done hellforleather, 1
# be ready i thought for almost anything, 1
# we struck a road i didnt recognize, 1
# but welcomed for the chance to lave my shoes, 1
# in dust once more we followed this a mile, 1
# perhaps to where it ended at a house, 1
# i didnt know was there it was the kind, 1
# to bring me to for broadboard paneling, 1
# i never saw so good a house deserted, 1
# excuse me if i ask you in a window, 1
# that happens to be broken davis said, 1
# the outside doors as yet have held against us, 1
# i want to introduce you to the people, 1
# who used to live here they were robinsons, 1
# you must have heard of clara robinson, 1
# the poetess who wrote the book of verses, 1
# and had it published it was all about, 1
# the posies on her inner windowsill, 1
# and the birds on her outer windowsill, 1
# and how she tended both or had them tended, 1
# she never tended anything herself, 1
# she was shut in for life she lived her whole, 1
# life long in bed and wrote her things in bed, 1
# ill show you how she had her sills extended, 1
# to entertain the birds and hold the flowers, 1
# our business firsts up attic with her books, 1
# we trod uncomfortably on crunching glass, 1
# through a house stripped of everything, 1
# except it seemed the poetesss poems, 1
# books i should say if books are what is needed, 1
# a whole edition in a packing case, 1
# that overflowing like a horn of plenty, 1
# or like the poetesss heart of love, 1
# had spilled them near the window toward the light, 1
# where driven rain had wet and swollen them, 1
# enough to stock a village library, 1
# unfortunately all of one kind though, 1
# they bad been brought home from some publisher, 1
# and taken thus into the family, 1
# boys and bad hunters had known what to do, 1
# with stone and lead to unprotected glass, 1
# shatter it inward on the unswept floors, 1
# how had the tender verse escaped their outrage, 1
# by being invisible for what it was, 1
# or else by some remoteness that defied them, 1
# to find out what to do to hurt a poem, 1
# yet oh the tempting flatness of a book, 1
# to send it sailing out the attic window, 1
# till it caught wind and opening out its covers, 1
# tried to improve on sailing like a tile, 1
# by flying like a bird silent in flight, 1
# but all the burden of its body song, 1
# only to tumble like a stricken bird, 1
# and lie in stones and bushes unretrieved, 1
# books were not thrown irreverently about, 1
# they simply lay where someone now and then, 1
# having tried one had dropped it at his feet, 1
# and left it lying where it fell rejected, 1
# here were all those the poetesss life, 1
# had been too short to sell or give away, 1
# take one old davis bade me graciously, 1
# why not take two or three, 1
# take all you want, 1
# goodlooking books like that he picked one fresh, 1
# in virgin wrapper from deep in the box, 1
# and stroked it with a hornyhanded kindness, 1
# he read in one and i read in another, 1
# both either looking for or finding something, 1
# the attic wasps went missing by like bullets, 1
# i was soon satisfied for the time being, 1
# all the way home i kept remembering, 1
# the small book in my pocket it was there, 1
# the poetess had sighed i knew in heaven, 1
# at having eased her heart of one more copy, 1
# legitimately my demand upon her, 1
# though slight was a demand she felt the tug, 1
# in time she would be rid of all her books, 1
# i stay, 1
# but it isnt as if, 1
# there wasnt always hudsons bay, 1
# and the fur trade, 1
# a small skiff, 1
# and a paddle blade, 1
# i can just see my tent pegged, 1
# and me on the floor, 1
# crosslegged, 1
# and a trapper looking in at the door, 1
# with furs to sell, 1
# his names joe, 1
# alias john, 1
# and between what he doesnt know, 1
# and wont tell, 1
# about where henry hudsons gone, 1
# i cant say hes much help, 1
# but we get on, 1
# the seal yelp, 1
# on an ice cake, 1
# its not men by some mistake, 1
# no, 1
# theres not a soul, 1
# for a windbreak, 1
# between me and the north pole—, 1
# except always johnjoe, 1
# my french indian esquimaux, 1
# and hes off setting traps, 1
# in one himself perhaps, 1
# give a headshake, 1
# over so much bay, 1
# thrown away, 1
# in snow and mist, 1
# that doesnt exist, 1
# i was going to say, 1
# for god man or beasts sake, 1
# yet does perhaps for all three, 1
# dont ask joe, 1
# what it is to him, 1
# its sometimes dim, 1
# what it is to me, 1
# unless it be, 1
# its the old captains dark fate, 1
# who failed to find or force a strait, 1
# in its twothousandmile coast, 1
# and his crew left him where be failed, 1
# ...
# a few old peckerfretted apple trees, 1
# make yourself up a cheering song of how, 1
# someones road home from work this once was, 1
# who may be just ahead of you on foot, 1
# or creaking with a buggy load of grain, 1
# the height of the adventure is the height, 1
# of country where two village cultures faded, 1
# into each other both of them are lost, 1
# and if youre lost enough to find yourself, 1
# by now pull in your ladder road behind you, 1
# and put a sign up closed to all but me, 1
# then make yourself at home the only field, 1
# now lefts no bigger than a harness gall, 1
# first theres the childrens house of makebelieve, 1
# some shattered dishes underneath a pine, 1
# the playthings in the playhouse of the children, 1
# weep for what little things could make them glad, 1
# then for the house that is no more a house, 1
# but only a belilaced cellar hole, 1
# now slowly closing like a dent in dough, 1
# this was no playhouse but a house in earnest, 1
# your destination and your destinys, 1
# a brook that was the water of the house, 1
# cold as a spring as yet so near its source, 1
# too lofty and original to rage, 1
# we know the valley streams that when aroused, 1
# will leave their tatters hung on barb and thorn, 1
# i have kept hidden in the instep arch, 1
# of an old cedar at the waterside, 1
# a broken drinking goblet like the grail, 1
# under a spell so the wrong ones cant find it, 1
# so cant get saved as saint mark says they mustnt, 1
# i stole the goblet from the childrens playhouse, 1
# here are your waters and your watering place, 1
# drink and be whole again beyond confusion, 1
# i walked down alone sunday after church, 1
# to the place where john has been cutting trees, 1
# to see for myself about the birch, 1
# he said i could have to bush my peas, 1
# the sun in the newcut narrow gap, 1
# was hot enough for the first of may, 1
# and stifling hot with the odor of sap, 1
# from stumps still bleeding their life away, 1
# the frogs that were peeping a thousand shrill, 1
# wherever the ground was low and wet, 1
# the minute they heard my step went still, 1
# to watch me and see what i came to get, 1
# birch boughs enough piled everywhere—, 1
# all fresh and sound from the recent axe, 1
# time someone came with cart and pair, 1
# and got them off the wild flowers backs, 1
# they might be good for garden things, 1
# to curl a little finger round, 1
# the same as you seize catscradle strings, 1
# and lift themselves up off the ground, 1
# small good to anything growing wild, 1
# they were crooking many a trillium, 1
# that had budded before the boughs were piled, 1
# and since it was coming up had to come, 1
# over back where they speak of life as staying, 1
# you couldnt call it living for it aint, 1
# there was an old old house renewed with paint, 1
# and in it a piano loudly playing, 1
# out in the plowed ground in the cold a digger, 1
# among unearthed potatoes standing still, 1
# was counting winter dinners one a hill, 1
# with half an ear to the pianos vigor, 1
# all that piano and new paint back there, 1
# was it some money suddenly come into, 1
# or some extravagance young love had been to, 1
# or old love on an impulse not to care, 1
# not to sink under being man and wife, 1
# but get some color and music out of life, 1
# it was long i lay, 1
# awake that night, 1
# wishing that night, 1
# would name the hour, 1
# and tell me whether, 1
# to call it day, 1
# though not yet light, 1
# and give up sleep, 1
# the snow fell deep, 1
# with the hiss of spray, 1
# two winds would meet, 1
# one down one street, 1
# one down another, 1
# and fight in a smother, 1
# of dust and feather, 1
# i could not say, 1
# but feared the cold, 1
# had checked the pace, 1
# of the tower clock, 1
# by tying together, 1
# its hands of gold, 1
# before its face, 1
# then cane one knock, 1
# a note unruffled, 1
# of earthly weather, 1
# though strange and muffled, 1
# the tower said one, 1
# and then a steeple, 1
# they spoke to themselves, 1
# and such few people, 1
# as winds might rouse, 1
# from sleeping warm, 1
# but not unhouse, 1
# they left the storm, 1
# that struck en masse, 1
# my window glass, 1
# like a beaded fur, 1
# in that grave one, 1
# they spoke of the sun, 1
# and moon and stars, 1
# saturn and mars, 1
# and jupiter, 1
# still more unfettered, 1
# they left the named, 1
# and spoke of the lettered, 1
# the sigmas and taus, 1
# of constellations, 1
# they filled their throats, 1
# with the furthest bodies, 1
# to which man sends his, 1
# speculation, 1
# beyond which god is, 1
# the cosmic motes, 1
# of yawning lenses, 1
# their solemn peals, 1
# were not their own, 1
# they spoke for the clock, 1
# with whose vast wheels, 1
# theirs interlock, 1
# in that grave word, 1
# uttered alone, 1
# the utmost star, 1
# trembled and stirred, 1
# though set so far, 1
# its whirling frenzies, 1
# appear like standing, 1
# in one self station, 1
# it has not ranged, 1
# and save for the wonder, 1
# of once expanding, 1
# to be a nova, 1
# it has not changed, 1
# to the eye of man, 1
# on planets over, 1
# around and under, 1
# it in creation, 1
# since man began, 1
# to drag down man, 1
# and nation nation, 1
# the surest thing there is is we are riders, 1
# and though none too successful at it guiders, 1
# through everything presented land and tide, 1
# and now the very air of what we ride, 1
# what is this talkedof mystery of birth, 1
# but being mounted bareback on the earth, 1
# we can just see the infant up astride, 1
# his small fist buried in the bushy hide, 1
# there is our wildest mount a headless horse, 1
# but though it runs unbridled off its course, 1
# and all our blandishments would seem defied, 1
# we have ideas yet that we havent tried, 1
# i let myself in at the kitchen door, 1
# its you she said i cant get up forgive me, 1
# not answering your knock i can no more, 1
# let people in than i can keep them out, 1
# im getting too old for my size i tell them, 1
# my fingers are about all ive the use of, 1
# sos to take any comfort i can sew, 1
# i help out with this beadwork what i can, 1
# thats a smart pair of pumps youre beading there, 1
# who are they for, 1
# you mean oh for some miss, 1
# i cant keep track of other peoples daughters, 1
# lord if i were to dream of everyone, 1
# whose shoes i primped to dance in, 1
# and wheres john, 1
# havent you seen him strange what set you off, 1
# to come to his house when hes gone to yours, 1
# you cant have passed each other i know what, 1
# he must have changed his mind and gone to garlands, 1
# he wont be long in that case you can wait, 1
# though what good you can be or anyone, 1
# its gone so far youve heard estelles run off, 1
# yes whats it all about when did she go, 1
# two weeks since, 1
# shes in earnest it appears, 1
# im sure she wont come back shes hiding somewhere, 1
# i dont know where myself john thinks i do, 1
# he thinks i only have to say the word, 1
# and shell come back but bless you im her mother, 1
# i cant talk to her and lord if i could, 1
# it will go hard with john what will he do, 1
# he cant find anyone to take her place, 1
# oh if you ask me that what will he do, 1
# he gets some sort of bakeshop meals together, 1
# with me to sit and tell him everything, 1
# whats wanted and how much and where it is, 1
# but when im gone of course i cant stay here, 1
# estelles to take me when shes settled down, 1
# he and i only hinder one another, 1
# i tell them they cant get me through the door though, 1
# ive been built in here like a big church organ, 1
# weve been here fifteen years, 1
# thats a long time, 1
# to live together and then pull apart, 1
# how do you see him living when youre gone, 1
# two of you out will leave an empty house, 1
# i dont just see him living many years, 1
# left here with nothing but the furniture, 1
# i hate to think of the old place when were gone, 1
# with the brook going by below the yard, 1
# and no one here but hens blowing about, 1
# if he could sell the place but then he cant, 1
# no one will ever live on it again, 1
# its too run down this is the last of it, 1
# what i think he will do is let things smash, 1
# hell sort of swear the time away hes awful, 1
# i never saw a man let family troubles, 1
# make so much difference in his mans affairs, 1
# hes just dropped everything hes like a child, 1
# i blame his being brought up by his mother, 1
# hes got hay down thats been rained on three times, 1
# he hoed a little yesterday for me, 1
# i thought the growing things would do him good, 1
# something went wrong i saw him throw the hoe, 1
# skyhigh with both hands i can see it now, 1
# come here ill show you in that apple tree, 1
# thats no way for a man to do at his age, 1
# hes fiftyfive you know if hes a day, 1
# arent you afraid of him whats that gun for, 1
# oh thats been there for hawks since chickentime, 1
# john hall touch me not if he knows his friends, 1
# ill say that for him johns no threatener, 1
# like some men folk no ones afraid of him, 1
# all is hes made up his mind not to stand, 1
# what he has got to stand, 1
# where is estelle, 1
# couldnt one talk to her what does she say, 1
# you say you dont know where she is, 1
# nor want to, 1
# she thinks if it was bad to live with him, 1
# it must be right to leave him, 1
# which is wrong, 1
# yes but he should have married her, 1
# i know, 1
# the strains been too much for her all these years, 1
# i cant explain it any other way, 1
# its different with a man at least with john, 1
# he knows hes kinder than the run of men, 1
# better than married ought to be as good, 1
# as married thats what he has always said, 1
# i know the way hes felt but all the same, 1
# i wonder why he doesnt marry her, 1
# and end it, 1
# too late now she wouldnt have him, 1
# hes given her time to think of something else, 1
# thats his mistake the dear knows my interest, 1
# has been to keep the thing from breaking up, 1
# this is a good home i dont ask for better, 1
# but when ive said why shouldnt they be married, 1
# hed say why should they no more words than that, 1
# and after all why should they johns been fair, 1
# i take it what was his was always hers, 1
# there was no quarrel about property, 1
# reason enough there was no property, 1
# a friend or two as good as own the farm, 1
# such as it is it isnt worth the mortgage, 1
# i mean estelle has always held the purse, 1
# the rights of that are harder to get at, 1
# i guess estelle and i have filled the purse, 1
# twas we let him have money not he us, 1
# johns a bad farmer im not blaming him, 1
# take it year in year out he doesnt make much, 1
# we came here for a home for me you know, 1
# estelle to do the housework for the board, 1
# of both of us but look how it turns out, 1
# she seems to have the housework and besides, 1
# half of the outdoor work though as for that, 1
# hed say she does it more because she likes it, 1
# you see our pretty things are all outdoors, 1
# our hens and cows and pigs are always better, 1
# than folks like us have any business with, 1
# farmers around twice as well off as we, 1
# havent as good they dont go with the farm, 1
# one thing you cant help liking about john, 1
# hes fond of nice things too fond some would say, 1
# but estelle dont complain shes like him there, 1
# she wants our hens to be the best there are, 1
# you never saw this room before a show, 1
# full of lank shivery halfdrowned birds, 1
# in separate coops having their plumage done, 1
# the smell of the wet feathers in the heat, 1
# you spoke of johns not being safe to stay with, 1
# you dont know what a gentle lot we are, 1
# we wouldnt hurt a hen you ought to see us, 1
# moving a flock of hens from place to place, 1
# were not allowed to take them upside down, 1
# all we can hold together by the legs, 1
# two at a times the rule one on each arm, 1
# no matter how far and how many times, 1
# we have to go, 1
# you mean thats johns idea, 1
# and we live up to it or i dont know, 1
# what childishness he wouldnt give way to, 1
# he manages to keep the upper hand, 1
# on his own farm hes boss but as to hens, 1
# we fence our flowers in and the hens range, 1
# nothings too good for them we say it pays, 1
# john likes to tell the offers he has had, 1
# twenty for this cock twentyfive for that, 1
# he never takes the money if theyre worth, 1
# that much to sell theyre worth as much to keep, 1
# bless you its all expense though reach me down, 1
# the little tin box on the cupboard shelf, 1
# the upper shelf the tin box thats the one, 1
# ill show you here you are, 1
# whats this, 1
# a bill, 1
# for fifty dollars for one langshang cock, 1
# receipted and the cock is in the yard, 1
# not in a glass case then, 1
# hed need a tall one, 1
# he can eat off a barrel from the ground, 1
# hes been in a glass case as you may say, 1
# the crystal palace london hes imported, 1
# john bought him and we paid the bill with beads, 1
# wampum i call it mind we dont complain, 1
# but you see dont you we take care of him, 1
# and like it too it makes it all the worse, 1
# it seems as if and thats not all hes helpless, 1
# in ways that i can hardly tell you of, 1
# sometimes he gets possessed to keep accounts, 1
# to see where all the money goes so fast, 1
# you know how men will be ridiculous, 1
# but its just fun the way he gets bedeviled, 1
# if hes untidy now what will he be  , 1
# it makes it all the worse you must be blind, 1
# estelles the one you neednt talk to me, 1
# cant you and i get to the root of it, 1
# whats the real trouble what will satisfy her, 1
# its as i say shes turned from him thats all, 1
# but why when shes well off is it the neighbours, 1
# being cut off from friends, 1
# we have our friends, 1
# that isnt it folks arent afraid of us, 1
# shes let it worry her you stood the strain, 1
# and youre her mother, 1
# but i didnt always, 1
# i didnt relish it along at first, 1
# but i got wonted to it and besides, 1
# john said i was too old to have grandchildren, 1
# but whats the use of talking when its done, 1
# she wont come back its worse than that she cant, 1
# why do you speak like that what do you know, 1
# what do you mean shes done harm to herself, 1
# i mean shes married married someone else, 1
# oho oho, 1
# you dont believe me, 1
# yes i do, 1
# only too well i knew there must be something, 1
# so that was what was back shes bad thats all, 1
# bad to get married when she had the chance, 1
# nonsense see whats she done but who who  , 1
# whod marry her straight out of such a mess, 1
# say it right out no matter for her mother, 1
# the man was found id better name no names, 1
# john himself wont imagine who he is, 1
# then its all up i think ill get away, 1
# youll be expecting john i pity estelle, 1
# i suppose she deserves some pity too, 1
# you ought to have the kitchen to yourself, 1
# to break it to him you may have the job, 1
# you neednt think youre going to get away, 1
# johns almost here ive had my eye on someone, 1
# coming down ryans hill i thought twas him, 1
# here he is now this box put it away, 1
# and this bill, 1
# whats the hurry hell unhitch, 1
# no he wont either hell just drop the reins, 1
# and turn doll out to pasture rig and all, 1
# she wont get far before the wheels hang up, 1
# on something theres no harm see there he is, 1
# my but he looks as if he must have heard, 1
# john threw the door wide but he didnt enter, 1
# how are you neighbour just the man im after, 1
# isnt it hell he said i want to know, 1
# come out here if you want to hear me talk, 1
# ill talk to you old woman afterward, 1
# ive got some news that maybe isnt news, 1
# what are they trying to do to me these two, 1
# do go along with him and stop his shouting, 1
# she raised her voice against the closing door, 1
# who wants to hear your news you dreadful fool, 1
# a winter garden in an alder swamp, 1
# where conies now come out to sun and romp, 1
# as near a paradise as it can be, 1
# and not melt snow or start a dormant tree, 1
# it lifts existence on a plane of snow, 1
# one level higher than the earth below, 1
# one level nearer heaven overhead, 1
# and last years berries shining scarlet red, 1
# it lifts a gaunt luxuriating beast, 1
# where he can stretch and hold his highest feat, 1
# on some wild apple trees young tender bark, 1
# what well may prove the years high girdle mark, 1
# so near to paradise all pairing ends, 1
# here loveless birds now flock as winter friends, 1
# content with budinspecting they presume, 1
# to say which buds are leaf and which are bloom, 1
# a featherhammer gives a double knock, 1
# this eden day is done at two oclock, 1
# an hour of winter day might seem too short, 1
# to make it worth lifes while to wake and sport, 1

# %%
train_text, test_text, Ytrain, Ytest = train_test_split(input_texts, labels)

# %%
len(Ytrain), len(Ytest)
# Out:
# (1615, 539)

# %%
train_text[:5]
# Out:
# ['while a bolder note than this might swell',
#  'estelle to do the housework for the board',
#  'then i dont know it must be strange enough',
#  'john likes to tell the offers he has had',
#  'by all i tell but sos the moon a witch']

# %%
Ytrain[:5]
# Out:
# [0, 1, 1, 1, 1]

# %%
idx = 1
word2idx = {'<unk>': 0}

# %%
for text in train_text:
    tokens = text.split()
    for token in tokens:
        if token not in word2idx:
            word2idx[token] = idx
            idx += 1

# %%
word2idx
# Out:
# {'<unk>': 0,
#  'while': 1,
#  'a': 2,
#  'bolder': 3,
#  'note': 4,
#  'than': 5,
#  'this': 6,
#  'might': 7,
#  'swell': 8,
#  'estelle': 9,
#  'to': 10,
#  'do': 11,
#  'the': 12,
#  'housework': 13,
#  'for': 14,
#  'board': 15,
#  'then': 16,
#  'i': 17,
#  'dont': 18,
#  'know': 19,
#  'it': 20,
#  'must': 21,
#  'be': 22,
#  'strange': 23,
#  'enough': 24,
#  'john': 25,
#  'likes': 26,
#  'tell': 27,
#  'offers': 28,
#  'he': 29,
#  'has': 30,
#  'had': 31,
#  'by': 32,
#  'all': 33,
#  'but': 34,
#  'sos': 35,
#  'moon': 36,
#  'witch': 37,
#  'takes': 38,
#  'suns': 39,
#  'wizard': 40,
#  'from': 41,
#  'thy': 42,
#  'holy': 43,
#  'throne': 44,
#  'above': 45,
#  'grief': 46,
#  'joy': 47,
#  'hate': 48,
#  'love': 49,
#  'where': 50,
#  'mighty': 51,
#  'of': 52,
#  'old': 53,
#  'have': 54,
#  'their': 55,
#  'home': 56,
#  'why': 57,
#  'not': 58,
#  'take': 59,
#  'two': 60,
#  'or': 61,
#  'three': 62,
#  'passionate': 63,
#  'light': 64,
#  'such': 65,
#  'his': 66,
#  'spirit': 67,
#  'was': 68,
#  'fit': 69,
#  'posies': 70,
#  'on': 71,
#  'her': 72,
#  'inner': 73,
#  'windowsill': 74,
#  'let': 75,
#  'people': 76,
#  'in': 77,
#  'can': 78,
#  'keep': 79,
#  'them': 80,
#  'out': 81,
#  'ought': 82,
#  'give': 83,
#  'purer': 84,
#  'oracle': 85,
#  'dyou': 86,
#  'person': 87,
#  'so': 88,
#  'related': 89,
#  'herself': 90,
#  'and': 91,
#  'came': 92,
#  'down': 93,
#  'like': 94,
#  'coasting': 95,
#  'child': 96,
#  'since': 97,
#  'flickers': 98,
#  'up': 99,
#  'heaven': 100,
#  'through': 101,
#  'night': 102,
#  'our': 103,
#  'talk': 104,
#  'been': 105,
#  'serious': 106,
#  'sober': 107,
#  'its': 108,
#  'too': 109,
#  'run': 110,
#  'is': 111,
#  'last': 112,
#  'thee': 113,
#  'poetry': 114,
#  'presence': 115,
#  'wave': 116,
#  'there': 117,
#  'ripple': 118,
#  'o': 119,
#  'care': 120,
#  'that': 121,
#  'my': 122,
#  'earthly': 123,
#  'lot': 124,
#  'even': 125,
#  'meridian': 126,
#  'glare': 127,
#  'day': 128,
#  'founts': 129,
#  'bliss': 130,
#  'one': 131,
#  'level': 132,
#  'nearer': 133,
#  'overhead': 134,
#  'begin': 135,
#  'over': 136,
#  'shed': 137,
#  'better': 138,
#  'stop': 139,
#  'call': 140,
#  'me': 141,
#  'back': 142,
#  'say': 143,
#  'goodbye': 144,
#  'only': 145,
#  'idled': 146,
#  'end': 147,
#  'far': 148,
#  'going': 149,
#  'forth': 150,
#  'song': 151,
#  'wild': 152,
#  'colonial': 153,
#  'boy': 154,
#  'rain': 155,
#  'sometime': 156,
#  'year': 157,
#  'doesnt': 158,
#  'make': 159,
#  'much': 160,
#  'plumes': 161,
#  'till': 162,
#  'they': 163,
#  'trailed': 164,
#  'dust': 165,
#  'seraphic': 166,
#  'glancing': 167,
#  'thine': 168,
#  'eyes': 169,
#  'whom': 170,
#  'sun': 171,
#  'dew': 172,
#  'broke': 173,
#  'trance': 174,
#  'you': 175,
#  'suspicious': 176,
#  'merry': 177,
#  'little': 178,
#  'throats': 179,
#  'helping': 180,
#  'cruel': 181,
#  'once': 182,
#  'him': 183,
#  'thats': 184,
#  'smart': 185,
#  'pair': 186,
#  'pumps': 187,
#  'youre': 188,
#  'beading': 189,
#  'fever': 190,
#  'moonbeam': 191,
#  'hangs': 192,
#  'oer': 193,
#  'folks': 194,
#  'were': 195,
#  'given': 196,
#  'plain': 197,
#  'speaking': 198,
#  'speculation': 199,
#  'how': 200,
#  'fairylike': 201,
#  'melody': 202,
#  'floats': 203,
#  'cannot': 204,
#  'guide': 205,
#  'us': 206,
#  'aright': 207,
#  'ridgepole': 208,
#  'stride': 209,
#  'broomstick': 210,
#  'figures': 211,
#  'described': 212,
#  'with': 213,
#  'at': 214,
#  'softmurmured': 215,
#  'words': 216,
#  'israfel': 217,
#  'stay': 218,
#  'as': 219,
#  'winds': 220,
#  'rouse': 221,
#  'set': 222,
#  'voices': 223,
#  'see': 224,
#  'if': 225,
#  'town': 226,
#  'wanted': 227,
#  'struck': 228,
#  'hand': 229,
#  'off': 230,
#  'brittle': 231,
#  'floor': 232,
#  'death': 233,
#  'looks': 234,
#  'gigantically': 235,
#  'lyre': 236,
#  'within': 237,
#  'sky': 238,
#  'good': 239,
#  'some': 240,
#  'are': 241,
#  'withdrawing': 242,
#  'into': 243,
#  'grave': 244,
#  'growing': 245,
#  'grown': 246,
#  'content': 247,
#  'budinspecting': 248,
#  'presume': 249,
#  'living': 250,
#  'when': 251,
#  'gone': 252,
#  'look': 253,
#  'sitting': 254,
#  'here': 255,
#  'another': 256,
#  'kitchen': 257,
#  'bedroom': 258,
#  'minute': 259,
#  'took': 260,
#  'less': 261,
#  'traveled': 262,
#  'stardials': 263,
#  'pointed': 264,
#  'morn': 265,
#  'own': 266,
#  'upturnd': 267,
#  'alas': 268,
#  'sorrow': 269,
#  'planets': 270,
#  'pallor': 271,
#  'strangely': 272,
#  'mistrust': 273,
#  'stamped': 274,
#  'said': 275,
#  'things': 276,
#  'himself': 277,
#  'age': 278,
#  'no': 279,
#  'more': 280,
#  'about': 281,
#  'does': 282,
#  'she': 283,
#  'maria': 284,
#  'thou': 285,
#  'hast': 286,
#  'heard': 287,
#  'hymn': 288,
#  'starlight': 289,
#  'pall': 290,
#  'first': 291,
#  'raspberry': 292,
#  'vines': 293,
#  'moisture': 294,
#  'color': 295,
#  'odor': 296,
#  'thicken': 297,
#  'just': 298,
#  'fun': 299,
#  'way': 300,
#  'gets': 301,
#  'bedeviled': 302,
#  'psyche': 303,
#  'uplifting': 304,
#  'finger': 305,
#  'virgin': 306,
#  'earth': 307,
#  'gave': 308,
#  'instant': 309,
#  'birth': 310,
#  'burning': 311,
#  'measures': 312,
#  'suit': 313,
#  'dear': 314,
#  'name': 315,
#  'text': 316,
#  'though': 317,
#  'bidden': 318,
#  'mistrusted': 319,
#  'none': 320,
#  'proud': 321,
#  'those': 322,
#  'will': 323,
#  'bear': 324,
#  'keeping': 325,
#  'still': 326,
#  'whose': 327,
#  'woods': 328,
#  'these': 329,
#  'think': 330,
#  'swollen': 331,
#  'tight': 332,
#  'buried': 333,
#  'under': 334,
#  'snow': 335,
#  'tent': 336,
#  'grove': 337,
#  'orchard': 338,
#  'solemn': 339,
#  'peals': 340,
#  'highest': 341,
#  'noon': 342,
#  'assailed': 343,
#  'monarchs': 344,
#  'high': 345,
#  'estate': 346,
#  'purified': 347,
#  'electric': 348,
#  'fire': 349,
#  'distinct': 350,
#  'duplicate': 351,
#  'horn': 352,
#  'budded': 353,
#  'before': 354,
#  'boughs': 355,
#  'piled': 356,
#  'oh': 357,
#  'hawks': 358,
#  'chickentime': 359,
#  'wire': 360,
#  'something': 361,
#  'men': 362,
#  'thered': 363,
#  'boston': 364,
#  'turn': 365,
#  'round': 366,
#  'got': 367,
#  'saying': 368,
#  'what': 369,
#  'yet': 370,
#  'tempting': 371,
#  'flatness': 372,
#  'book': 373,
#  'we': 374,
#  'many': 375,
#  'visions': 376,
#  'maiden': 377,
#  'save': 378,
#  'divine': 379,
#  'wont': 380,
#  'teased': 381,
#  'wet': 382,
#  'am': 383,
#  'cant': 384,
#  'track': 385,
#  'other': 386,
#  'peoples': 387,
#  'daughters': 388,
#  'faith': 389,
#  'godliness': 390,
#  'arent': 391,
#  'afraid': 392,
#  'whats': 393,
#  'gun': 394,
#  'names': 395,
#  'joe': 396,
#  'shrines': 397,
#  'palaces': 398,
#  'towers': 399,
#  'sorry': 400,
#  'ever': 401,
#  'left': 402,
#  'road': 403,
#  'knew': 404,
#  'leaves': 405,
#  'step': 406,
#  'trodden': 407,
#  'black': 408,
#  'mustnt': 409,
#  'hard': 410,
#  'new': 411,
#  'comers': 412,
#  'saw': 413,
#  'position': 414,
#  'hands—': 415,
#  'facts': 416,
#  'want': 417,
#  'go': 418,
#  'safely': 419,
#  'may': 420,
#  'trust': 421,
#  'gleaming': 422,
#  'higher': 423,
#  'below': 424,
#  'spoke': 425,
#  'skyhigh': 426,
#  'both': 427,
#  'hands': 428,
#  'now': 429,
#  'could': 430,
#  'thought': 431,
#  'dead': 432,
#  'souls': 433,
#  'hear': 434,
#  'today': 435,
#  'ghoulhaunted': 436,
#  'woodland': 437,
#  'weir': 438,
#  'however': 439,
#  'bricks': 440,
#  'bring': 441,
#  'broadboard': 442,
#  'paneling': 443,
#  'fabric': 444,
#  'half': 445,
#  'fair': 446,
#  'son': 447,
#  'cellar': 448,
#  'forty': 449,
#  'years': 450,
#  'ago': 451,
#  'lets': 452,
#  'ceasing': 453,
#  'hymns': 454,
#  'attend': 455,
#  'spell': 456,
#  'world': 457,
#  'sweets': 458,
#  'sours': 459,
#  'wasnt': 460,
#  'always': 461,
#  'hudsons': 462,
#  'bay': 463,
#  'mistake': 464,
#  'which': 465,
#  'headed': 466,
#  'for—': 467,
#  'long': 468,
#  'case': 469,
#  'wait': 470,
#  'speel': 471,
#  'every': 472,
#  'single': 473,
#  'lizard': 474,
#  'unembodied': 475,
#  'essence': 476,
#  'blotting': 477,
#  'utterly': 478,
#  'nor': 479,
#  'grannys': 480,
#  'surely': 481,
#  'riddle': 482,
#  'your': 483,
#  'genealogy': 484,
#  'put': 485,
#  'thinks': 486,
#  'dark': 487,
#  'flooded': 488,
#  'daylight': 489,
#  'should': 490,
#  'shouldnt': 491,
#  'times': 492,
#  'flattered': 493,
#  'towns': 494,
#  'fighting': 495,
#  'groan': 496,
#  'roll': 497,
#  'mount': 498,
#  'yaanek': 499,
#  'ill': 500,
#  'show': 501,
#  'come': 502,
#  'past': 503,
#  'stars': 504,
#  'lion': 505,
#  'bowed': 506,
#  'grace': 507,
#  'natural': 508,
#  'law': 509,
#  'carry': 510,
#  'again': 511,
#  'speak': 512,
#  'hadnt': 513,
#  'gnawed': 514,
#  'hitching': 515,
#  'posts': 516,
#  'theirs': 517,
#  'interlock': 518,
#  'transforming': 519,
#  'charms': 520,
#  'shall': 521,
#  'please': 522,
#  'place': 523,
#  'raining': 524,
#  'sproutlands': 525,
#  'flourish': 526,
#  'axe': 527,
#  'longer': 528,
#  'feel': 529,
#  'hurried': 530,
#  'sell': 531,
#  'theyre': 532,
#  'worth': 533,
#  'everybody': 534,
#  'proof': 535,
#  'mad': 536,
#  'fell': 537,
#  'faces': 538,
#  'roses': 539,
#  'pay': 540,
#  'different': 541,
#  'man': 542,
#  'least': 543,
#  'worlds': 544,
#  'god': 545,
#  'funereal': 546,
#  'mind': 547,
#  'garden': 548,
#  'father': 549,
#  'upstairs': 550,
#  'mother': 551,
#  'downstairs': 552,
#  'sign': 553,
#  'spose': 554,
#  'mallice': 555,
#  'huse': 556,
#  'conquered': 557,
#  'scruples': 558,
#  'gloom': 559,
#  'either': 560,
#  'cloud': 561,
#  'smoke': 562,
#  'davis': 563,
#  'owned': 564,
#  'solid': 565,
#  'mica': 566,
#  'mountain': 567,
#  'weve': 568,
#  'fifteen': 569,
#  'eye': 570,
#  'made': 571,
#  'tutelar': 572,
#  'shrine': 573,
#  'vast': 574,
#  'forms': 575,
#  'move': 576,
#  'fantastically': 577,
#  'fate': 578,
#  'july': 579,
#  'midnight': 580,
#  'ancestral': 581,
#  'memories': 582,
#  'together': 583,
#  'unhouse': 584,
#  'across': 585,
#  'sacred': 586,
#  'sill': 587,
#  'wonted': 588,
#  'besides': 589,
#  'hes': 590,
#  'stand': 591,
#  'mortal': 592,
#  'travellers': 593,
#  'valley': 594,
#  'great': 595,
#  'monolithic': 596,
#  'knees': 597,
#  'former': 598,
#  'darkest': 599,
#  'evening': 600,
#  'lantern': 601,
#  'did': 602,
#  'chores': 603,
#  'happier': 604,
#  'sweet': 605,
#  'provision': 606,
#  'meeting': 607,
#  'strains': 608,
#  'torn': 609,
#  'naiad': 610,
#  'flood': 611,
#  'telling': 612,
#  'sigh': 613,
#  'fullorbed': 614,
#  'soul': 615,
#  'soaring': 616,
#  'remembered': 617,
#  'dank': 618,
#  'tarn': 619,
#  'auber': 620,
#  'drawn': 621,
#  'hearts': 622,
#  'passion': 623,
#  'tone': 624,
#  'im': 625,
#  'stark': 626,
#  'drew': 627,
#  'passport': 628,
#  'henry': 629,
#  'bad': 630,
#  'brought': 631,
#  'publisher': 632,
#  'tower': 633,
#  'clock': 634,
#  'mowing': 635,
#  'field': 636,
#  'headshake': 637,
#  'hall': 638,
#  'door': 639,
#  'novelty': 640,
#  'youve': 641,
#  'sought': 642,
#  'precipitate': 643,
#  'pathway': 644,
#  'bird': 645,
#  'alight': 646,
#  'fresh': 647,
#  'sound': 648,
#  'recent': 649,
#  'seek': 650,
#  'treasure': 651,
#  'jewelled': 652,
#  'skies': 653,
#  'get': 654,
#  'poetess': 655,
#  'sighed': 656,
#  'surprised': 657,
#  'lie': 658,
#  'nearest': 659,
#  'resembles': 660,
#  'worship': 661,
#  'remember': 662,
#  'mean': 663,
#  'held': 664,
#  'purse': 665,
#  'glass': 666,
#  'ask': 667,
#  'leaf': 668,
#  'bough': 669,
#  'street': 670,
#  'hinted': 671,
#  'heartstrings': 672,
#  'dawn': 673,
#  'upon': 674,
#  'desolate': 675,
#  'coming': 676,
#  'arthur': 677,
#  'amy': 678,
#  'who': 679,
#  'claiming': 680,
#  'priority': 681,
#  'starkness': 682,
#  'mossy': 683,
#  'banks': 684,
#  'meandering': 685,
#  'paths': 686,
#  'beauty': 687,
#  'stock': 688,
#  'village': 689,
#  'library': 690,
#  '2o3': 691,
#  'attic': 692,
#  'went': 693,
#  'swamp': 694,
#  'cedar': 695,
#  'choked': 696,
#  'oil': 697,
#  'pass': 698,
#  'small': 699,
#  'skiff': 700,
#  'legended': 701,
#  'tomb': 702,
#  'money': 703,
#  'suddenly': 704,
#  'seriously': 705,
#  'bearings': 706,
#  'astartes': 707,
#  'bediamonded': 708,
#  'crescent': 709,
#  'rare': 710,
#  'radiant': 711,
#  'flowers': 712,
#  'houses': 713,
#  'well': 714,
#  'tried': 715,
#  'improve': 716,
#  'sailing': 717,
#  'tile': 718,
#  'nothing': 719,
#  'furniture': 720,
#  'enamored': 721,
#  'i—': 722,
#  'wind': 723,
#  'dared': 724,
#  'stir': 725,
#  'unless': 726,
#  'tiptoe': 727,
#  'sanctified': 728,
#  'elysian': 729,
#  'whir': 730,
#  'birds': 731,
#  'warm': 732,
#  'bed': 733,
#  'thing': 734,
#  'help': 735,
#  'liking': 736,
#  'miss': 737,
#  'captains': 738,
#  'sleeping': 739,
#  'never': 740,
#  'thinking': 741,
#  'feared': 742,
#  'cold': 743,
#  'sure': 744,
#  'shes': 745,
#  'hiding': 746,
#  'somewhere': 747,
#  'neck': 748,
#  'spare': 749,
#  'clothes': 750,
#  'stove': 751,
#  'gourd': 752,
#  'grape': 753,
#  'luxuriant': 754,
#  'grew': 755,
#  'bade': 756,
#  'graciously': 757,
#  'sat': 758,
#  'shouted': 759,
#  'toffile': 760,
#  'anything': 761,
#  'ye': 762,
#  'avengers': 763,
#  'libertys': 764,
#  'wrongs': 765,
#  'utmost': 766,
#  'star': 767,
#  'tempt': 768,
#  'waters': 769,
#  'wish': 770,
#  'consideration': 771,
#  'chimneys': 772,
#  'false': 773,
#  'foot': 774,
#  'without': 775,
#  'avail': 776,
#  'having': 777,
#  'happened': 778,
#  'bells': 779,
#  'absence': 780,
#  'thoughts': 781,
#  'entombed': 782,
#  'hopes': 783,
#  'an': 784,
#  'ice': 785,
#  'cake': 786,
#  'chisel': 787,
#  'work': 788,
#  'enormous': 789,
#  'glacier': 790,
#  'tempted': 791,
#  'stone': 792,
#  'lead': 793,
#  'unprotected': 794,
#  'barn': 795,
#  'smells': 796,
#  'wash': 797,
#  'ploughed': 798,
#  'ground': 799,
#  'arose': 800,
#  'tis': 801,
#  'feeling': 802,
#  'failed': 803,
#  'find': 804,
#  'force': 805,
#  'strait': 806,
#  'noted': 807,
#  'tumultuous': 808,
#  'sea': 809,
#  'house': 810,
#  'sills': 811,
#  'extended': 812,
#  'apple': 813,
#  'trees': 814,
#  'young': 815,
#  'tender': 816,
#  'bark': 817,
#  'flight': 818,
#  'read': 819,
#  'familiar': 820,
#  'spirits': 821,
#  'replied': 822,
#  'dreaming': 823,
#  'closes': 824,
#  'path': 825,
#  'among': 826,
#  'buttons': 827,
#  'poured': 828,
#  'lap': 829,
#  'uplifted': 830,
#  'cried': 831,
#  'october': 832,
#  'sit': 833,
#  'open': 834,
#  'makes': 835,
#  'head': 836,
#  'spin': 837,
#  'hot': 838,
#  'furs': 839,
#  'tree': 840,
#  'beside': 841,
#  'wall': 842,
#  'stands': 843,
#  'bare': 844,
#  'strength': 845,
#  'subdued': 846,
#  'meaning': 847,
#  'wheels': 848,
#  'hang': 849,
#  'seraph': 850,
#  'harper': 851,
#  'thrown': 852,
#  'aside': 853,
#  'horse': 854,
#  'queer': 855,
#  'friends': 856,
#  'riches': 857,
#  'beasts': 858,
#  'sake': 859,
#  'wrong': 860,
#  'throw': 861,
#  'hoe': 862,
#  'except': 863,
#  'johnjoe': 864,
#  'simply': 865,
#  'lay': 866,
#  'someone': 867,
#  'knows': 868,
#  'story': 869,
#  'twas': 870,
#  'started': 871,
#  'courting': 872,
#  'bones': 873,
#  'skeleton': 874,
#  'shadow': 875,
#  'perfect': 876,
#  'any': 877,
#  'business': 878,
#  'smell': 879,
#  'drowned': 880,
#  'state': 881,
#  'glory': 882,
#  'befitting': 883,
#  'entablatures': 884,
#  'intertwine': 885,
#  'very': 886,
#  'hours': 887,
#  'breathing': 888,
#  'low': 889,
#  'ready': 890,
#  'outsiders': 891,
#  'weak': 892,
#  'lines': 893,
#  'written': 894,
#  'magic': 895,
#  'turns': 896,
#  'theyve': 897,
#  'dragged': 898,
#  'courts': 899,
#  'deal': 900,
#  'masonry': 901,
#  'shut': 902,
#  'life': 903,
#  'lived': 904,
#  'whole': 905,
#  'nowadays': 906,
#  'fulfilled': 907,
#  'pipe': 908,
#  'mouth': 909,
#  'brown': 910,
#  'jug': 911,
#  'halting': 912,
#  'perplexed': 913,
#  'behind': 914,
#  'barrier': 915,
#  'nausicaa': 916,
#  'timber': 917,
#  'lonesome': 918,
#  'hideous': 919,
#  'throng': 920,
#  'rush': 921,
#  'forever': 922,
#  'blandishments': 923,
#  'would': 924,
#  'seem': 925,
#  'defied': 926,
#  'hell': 927,
#  'sort': 928,
#  'swear': 929,
#  'time': 930,
#  'away': 931,
#  'awful': 932,
#  'suspect': 933,
#  'motorcars': 934,
#  'asked': 935,
#  'sudden': 936,
#  'movement': 937,
#  'toward': 938,
#  'bodice': 939,
#  'evil': 940,
#  'robes': 941,
#  'warrant': 942,
#  'fervour': 943,
#  'power': 944,
#  'anyone': 945,
#  'burden': 946,
#  'body': 947,
#  'wearing': 948,
#  'deep': 949,
#  'crown': 950,
#  'remaining': 951,
#  'aster': 952,
#  'flower': 953,
#  'nova': 954,
#  'alias': 955,
#  'hour': 956,
#  'wrought': 957,
#  'breath': 958,
#  'storm': 959,
#  'used': 960,
#  'live': 961,
#  'robinsons': 962,
#  'seems': 963,
#  'wonder': 964,
#  'marry': 965,
#  'gather': 966,
#  'atmosphere': 967,
#  'cutting': 968,
#  'ghost—': 969,
#  'sends': 970,
#  'gives': 971,
#  'glimpses': 972,
#  'fancied': 973,
#  'looked': 974,
#  'six': 975,
#  'oclock': 976,
#  'receipted': 977,
#  'cock': 978,
#  'yard': 979,
#  'pause': 980,
#  'gardengate': 981,
#  'reply': 982,
#  'hers': 983,
#  'intelligence': 984,
#  'warmer': 985,
#  'dian': 986,
#  '‘tis': 987,
#  'vault': 988,
#  'lost': 989,
#  'ulalume': 990,
#  'lavas': 991,
#  'restlessly': 992,
#  'springs': 993,
#  'neer': 994,
#  'flow': 995,
#  'silver': 996,
#  'lies': 997,
#  'charred': 998,
#  'politician': 999,
#  ...}

# %%
len(word2idx)
# Out:
# 2513

# %%
train_text_int = []
test_text_int = []

for text in train_text:
    tokens = text.split()
    line_as_int = [word2idx[token] for token in tokens]
    train_text_int.append(line_as_int)
    
for text in test_text:
    tokens = text.split()
    line_as_int = [word2idx.get(token, 0) for token in tokens]
    test_text_int.append(line_as_int)

# %%
train_text_int[100:105]
# Out:
# [[200, 375, 376, 52, 2, 377, 121, 111],
#  [378, 145, 12, 379, 64, 77, 168, 169],
#  [17, 380, 22, 381, 34, 224, 200, 382, 17, 383],
#  [17, 384, 79, 385, 52, 386, 387, 388],
#  [317, 58, 213, 389, 213, 390, 327, 44]]

# %%
test_text_int[10:15]
# Out:
# [[0, 10, 0, 10, 0],
#  [33, 1518, 52, 80, 10, 0, 369, 602, 121, 1822],
#  [81, 77, 12, 0, 799, 77, 12, 743, 2, 0],
#  [506, 2416, 71, 12, 567, 1832, 99],
#  [679, 2482, 924, 2150, 41, 903, 91, 100]]

# %%
V = len(word2idx)

A0 = np.ones((V, V))
pi0 = np.ones(V)

A1 = np.ones((V, V))
pi1 = np.ones(V)

# %%
def compute_counts(text_as_int, A, pi):
    for tokens in text_as_int:
        last_idx = None
        for idx in tokens:
            if last_idx is None:
                pi[idx] += 1
            else:
                A[last_idx, idx] += 1
            
            last_idx = idx
            

compute_counts([t for t, y in zip(train_text_int, Ytrain) if y == 0], A0, pi0)
compute_counts([t for t, y in zip(train_text_int, Ytrain) if y == 1], A1, pi1)

# %%
A0 /= A0.sum(axis=1, keepdims=True)
pi0 /= pi0.sum()

A1 /= A1.sum(axis=1, keepdims=True)
pi1 /= pi1.sum()

# %%
logA0 = np.log(A0)
logpi0 = np.log(pi0)

logA1 = np.log(A1)
logpi1 = np.log(pi1)

# %%
count0 = sum(y == 0 for y in Ytrain)
count1 = sum(y == 1 for y in Ytrain)
total = len(Ytrain)
p0 = count0 / total
p1 = count1 / total
logp0 = np.log(p0)
logp1 = np.log(p1)
p0, p1
# Out:
# (0.3256965944272446, 0.6743034055727554)

# %%
class Classifier:
  def __init__(self, logAs, logpis, logpriors):
    self.logAs = logAs
    self.logpis = logpis
    self.logpriors = logpriors
    self.K = len(logpriors)

  def _compute_log_likelihood(self, input_, class_):
    logA = self.logAs[class_]
    logpi = self.logpis[class_]

    last_idx = None
    logprob = 0
    for idx in input_:
      if last_idx is None:
        logprob += logpi[idx]
      else:
        logprob += logA[last_idx, idx]
      
      last_idx = idx
    
    return logprob
  
  def predict(self, inputs):
    predictions = np.zeros(len(inputs))
    for i, input_ in enumerate(inputs):
      posteriors = [self._compute_log_likelihood(input_, c) + self.logpriors[c] \
             for c in range(self.K)]
      pred = np.argmax(posteriors)
      predictions[i] = pred
    return predictions

# %%
clf = Classifier([logA0, logA1], [logpi0, logpi1], [logp0, logp1])

# %%
Ptrain = clf.predict(train_text_int)
print(f"Train acc: {np.mean(Ptrain == Ytrain)}")
# Out:
# Train acc: 0.9956656346749226

# %%
Ptest = clf.predict(test_text_int)
print(f"Test acc: {np.mean(Ptest == Ytest)}")
# Out:
# Test acc: 0.7884972170686456

# %%
from sklearn.metrics import confusion_matrix, f1_score

# %%
cm = confusion_matrix(Ytrain, Ptrain)
cm
# Out:
# array([[ 519,    7],
#        [   0, 1089]], dtype=int64)

# %%
cm_test = confusion_matrix(Ytest, Ptest)
cm_test
# Out:
# array([[ 91, 101],
#        [ 13, 334]], dtype=int64)

# %%
f1_score(Ytrain, Ptrain)
# Out:
# 0.9967963386727688

# %%
f1_score(Ytest, Ptest)
# Out:
# 0.8542199488491049
